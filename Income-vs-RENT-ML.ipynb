# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("income-rent.csv")
df.head()
# Out:
#    Income  Rent
# 0    2300   950
# 1    1400   500
# 2    2400  1000
# 3    5250  1800
# 4    4375  1600

# %%
df.shape
df.isnull().sum()
df.dtypes
df.describe()
# Out:
#            Income         Rent
# count    10.00000    10.000000
# mean   2927.50000  1110.000000
# std    1473.20748   568.037557
# min    1400.00000   500.000000
# 25%    1650.00000   600.000000
# 50%    2350.00000   975.000000
# 75%    4318.75000  1712.500000
# max    5250.00000  1800.000000

# %%
plt.scatter(df['Income'],df['Rent'])
plt.xlabel("Income")
plt.ylabel("Rent")
plt.title("Income vs Rent")
plt.grid(True)
plt.show()

# %%
x = df[['Income']]
y = df['Rent']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error (MSE): 39260.82977870073
# R² Score: 0.9070749591036669

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 0.3569910244475529
# Intercept (c): 41.298493122726086

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual')
plt.plot(x_test, y_pred, color='red', label='Predicted Line')
plt.xlabel("Income")
plt.ylabel("Rent")
plt.title("Actual vs Predicted Rent")
plt.legend()
plt.grid(True)
plt.show()
